# %%
import matplotlib.pyplot
import numpy

# %%
arthritis = numpy.loadtxt(fname ='data/inflammation-01.csv', delimiter = ',')

# %%
image = matplotlib.pyplot.imshow(arthritis)
matplotlib.pyplot.show()

# %%
average_inflammation = arthritis.mean(axis=0)
average_plot = matplotlib.pyplot.plot(average_inflammation)
matplotlib.pyplot.show()

# %%
max_inflammation_plot = matplotlib.pyplot.plot(arthritis.max(axis=0))
matplotlib.pyplot.show()

# %% [markdown]
# # Subplotting

# %%
import numpy as np
import matplotlib.pyplot as plt

arthritis = np.loadtxt(fname = 'python-novice-inflammation-data/data/inflammation-01.csv', delimiter=',')

figure = plt.figure(figsize = (10,3))

axes1 = figure.add_subplot(1,3,1) # 1 row, 3 columns, 1st graph
axes2 = figure.add_subplot(1,3,2)
axes3 = figure.add_subplot(1,3,3)

axes1.set_ylabel('average')
axes1.plot(arthritis.mean(axis = 0))

axes2.set_ylabel('maximum')
axes2.plot(arthritis.max(axis = 0))

axes3.set_ylabel('minimum')
axes3.plot(arthritis.min(axis = 0))

figure.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

arthritis = np.loadtxt(fname = 'python-novice-inflammation-data/data/inflammation-01.csv', delimiter=',')

figure = plt.figure(figsize = (3,10))

axes1 = figure.add_subplot(3,1,1) # 1 row, 3 columns, 1st graph
axes2 = figure.add_subplot(3,1,2)
axes3 = figure.add_subplot(3,1,3)

axes1.set_ylabel('average')
axes1.plot(arthritis.mean(axis = 0))

axes2.set_ylabel('maximum')
axes2.plot(arthritis.max(axis = 0))

axes3.set_ylabel('minimum')
axes3.plot(arthritis.min(axis = 0))

figure.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

arthritis = np.loadtxt(fname = 'data/inflammation-01.csv', delimiter=',')

figure = plt.figure(figsize = (10,3))

axes1 = figure.add_subplot(3,1,1) # 1 row, 3 columns, 1st graph
axes2 = figure.add_subplot(3,1,2)
axes3 = figure.add_subplot(3,1,3)

axes1.set_ylabel('average')
axes1.plot(arthritis.mean(axis = 0))

axes2.set_ylabel('maximum')
axes2.plot(arthritis.max(axis = 0))

axes3.set_ylabel('minimum')
axes3.plot(arthritis.min(axis = 0))

figure.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 arthritis = np.loadtxt(fname = 'data/inflammation-01.csv', delimiter=',')
#       6 figure = plt.figure(figsize = (10,3))
#       8 axes1 = figure.add_subplot(3,1,1) # 1 row, 3 columns, 1st graph
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:1067, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065     fname = os_fspath(fname)
#    1066 if _is_string_like(fname):
# -> 1067     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068     fencoding = getattr(fh, 'encoding', 'latin1')
#    1069     fh = iter(fh)
#
# ...
